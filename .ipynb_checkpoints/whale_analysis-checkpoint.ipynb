# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
## Reading whale returns
#Set the file paths
whale_returns_data = Path("Resources/whale_returns.csv")

#Read the CSV file and set the 'date' column as a datetime index to the DataFrame
whale_returns = pd.read_csv(whale_returns_data, index_col="Date", infer_datetime_format=True, parse_dates=True)

#Sort data by Date in ascending order
whale_returns.sort_index(ascending=True, inplace=True)

#Displaying a few rows
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns.dropna(inplace=True)
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
## Reading algorithmic returns
#Set the file paths
algo_returns_data = Path("Resources/algo_returns.csv")

#Read the CSV file and set the 'date' column as a datetime index to the DataFrame
algo_returns = pd.read_csv(algo_returns_data, index_col="Date", infer_datetime_format=True, parse_dates=True)

#Sort data by Date in ascending order
algo_returns.sort_index(ascending=True, inplace=True)

#Displaying a few rows
algo_returns.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns.dropna(inplace=True)
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
## Reading S&P 500 Closing Prices
#Set the file paths
sp500_history_data = Path("Resources/sp500_history.csv")

#Read the CSV file and set the 'date' column as a datetime index to the DataFrame
sp500_history = pd.read_csv(sp500_history_data, index_col="Date", infer_datetime_format=True, parse_dates=True)

#Sort data by Date in ascending order
sp500_history.sort_index(ascending=True, inplace=True)

#Displaying a few rows
sp500_history.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history["Close"] = sp500_history["Close"].str.replace("$", "")
sp500_history["Close"] = sp500_history["Close"].astype("float")
sp500_history.sort_index(inplace = True)
sp500_history.head()
# Out:
# C:\Users\eduar\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Calculate Daily Returns
sp500_returns = sp500_history.pct_change()
sp500_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
sp500_returns.dropna(inplace=True)
sp500_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns.rename(columns = {"Close":"sp500"}, inplace=True)
sp500_returns.head()
# Out:
#                sp500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
df_daily_returns = pd.concat([whale_returns, algo_returns, sp500_returns], axis="columns", join="inner")
df_daily_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     sp500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Analysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
df_daily_returns.plot(figsize = (20,10), title="Daily Returns")
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
df_cumulative_returns = (1 + df_daily_returns).cumprod()

# Plot cumulative returns
df_cumulative_returns.plot(figsize= (20,10), title="Cumulative Returns")
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
df_daily_returns.boxplot(figsize= (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
df_returns_std = df_daily_returns.std()
df_returns_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# sp500                          0.008554
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P500
print(f"S&P 500 STD:",(df_returns_std[6]))
print("                                                 ")   

# Determine which portfolios are riskier than the S&P 500
print(df_returns_std > df_returns_std[6])
print("                                                 ") 
print(f"Porfolios riskier than the S&P 500: TIGER GLOBAL MANAGEMENT LLC & BERKSHIRE HATHAWAY INC.")
# Out:
# S&P 500 STD: 0.008553731597758204
#
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# sp500                          False
# dtype: bool
#
# Porfolios riskier than the S&P 500: TIGER GLOBAL MANAGEMENT LLC & BERKSHIRE HATHAWAY INC.

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
df_annualized_std = df_returns_std*np.sqrt(252)
df_annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# sp500                          0.135786
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
df_rolling_21 = df_daily_returns.rolling(window = 21).std()

# Plot the rolling standard deviation
df_rolling_21.plot(figsize=(20,10), title="Rolling 21-Day Std. Returns")
# Out:
# <AxesSubplot:title={'center':'Rolling 21-Day Std. Returns'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
df_returns_correlation = df_daily_returns.corr()

# Display de correlation matrix
df_returns_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# sp500                                         0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
berkshire_covariance = df_daily_returns["BERKSHIRE HATHAWAY INC"].rolling(window=60).cov(df_daily_returns["sp500"])

# Calculate variance of S&P 500
sp500_variance = df_daily_returns["sp500"].rolling(window=60).var()

# Computing beta
berkshire_beta = berkshire_covariance / sp500_variance

# Plot beta trend
berkshire_beta.plot(figsize=(20,10), title="Rolling 60-Day Beta of BHI")
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of BHI'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
df_daily_returns.ewm(halflife=21, adjust=True).std()
df_daily_returns.ewm(halflife=21, adjust=True).std().plot(figsize =(20,10), title="Exponentially Weighted Average")
# Out:
# <AxesSubplot:title={'center':'Exponentially Weighted Average'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
df_sharpe_ratio = (df_daily_returns.mean() * 252) / (df_daily_returns.std() * np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot
df_sharpe_ratio.plot(kind="bar", figsize=(20,10), title="Sharpe Ratio")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratio'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---Algo 1 did outperform the S&P 500 and the whales portfolios while Algo 2 did not outperform S&P 500 and BHI portfolios.

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
## Reading data from 1st stock
#Set the file paths
aapl_historical_data = Path("Resources/aapl_historical.csv")

#Read the CSV file and set the 'date' column as a datetime index to the DataFrame
aapl_historical = pd.read_csv(aapl_historical_data, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)

#Sort data by Date in ascending order
aapl_historical.sort_index(ascending=True, inplace=True)

#Displaying a few rows
aapl_historical.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   AAPL  188.59
# 2018-05-14   AAPL  188.15
# 2018-05-15   AAPL  186.44
# 2018-05-16   AAPL  188.18
# 2018-05-17   AAPL  186.99

# %%
## Reading data from 2nd stock
#Set the file paths
cost_historical_data = Path("Resources/cost_historical.csv")

#Read the CSV file and set the 'date' column as a datetime index to the DataFrame
cost_historical = pd.read_csv(cost_historical_data, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)

#Sort data by Date in ascending order
cost_historical.sort_index(ascending=True, inplace=True)

#Displaying a few rows
cost_historical.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   COST  195.76
# 2018-05-14   COST  195.88
# 2018-05-15   COST  195.48
# 2018-05-16   COST  198.71
# 2018-05-17   COST  199.60

# %%
# Reading data from 3rd stock
#Set the file paths
goog_historical_data = Path("Resources/goog_historical.csv")

#Read the CSV file and set the 'date' column as a datetime index to the DataFrame
goog_historical = pd.read_csv(goog_historical_data, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)

#Sort data by Date in ascending order
goog_historical.sort_index(ascending=True, inplace=True)

#Displaying a few rows
goog_historical.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
# Combine all stocks in a single DataFrame
my_historical = pd.concat([aapl_historical, cost_historical, goog_historical], axis="columns", join="inner")
my_historical.head()
# Out:
#            Symbol    NOCP Symbol    NOCP Symbol     NOCP
# Trade DATE
# 2018-05-11   AAPL  188.59   COST  195.76   GOOG  1098.26
# 2018-05-14   AAPL  188.15   COST  195.88   GOOG  1100.20
# 2018-05-15   AAPL  186.44   COST  195.48   GOOG  1079.23
# 2018-05-16   AAPL  188.18   COST  198.71   GOOG  1081.77
# 2018-05-17   AAPL  186.99   COST  199.60   GOOG  1078.59

# %%
# Reset Date index
my_historical.index = my_historical.index.normalize()

# %%
## Reorganize portfolio data by having a column per symbol
#Renaming columns in single Dataframe
my_historical.columns = ["symbol", "AAPL", "symbol", "COST", "symbol", "GOOG"]

#Drop all the symbol columns
my_historical.drop(my_historical.columns[[0,2,4]], axis=1, inplace=True)

#Renaming the index
my_historical.index.names = ["Date"]
my_historical.head()
# Out:
#               AAPL    COST     GOOG
# Date
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Calculate daily returns
my_returns = my_historical.pct_change()

# Drop NAs
my_returns.dropna(inplace=True)

# Display sample data
my_returns.head()
# Out:
#                 AAPL      COST      GOOG
# Date
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
my_portfolio_returns = my_returns.dot(weights)
my_portfolio_returns.dropna(inplace=True)

# Display sample data
my_portfolio_returns.head()
# Out:
# Date
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
portfolio_returns = pd.concat((my_portfolio_returns, df_daily_returns), axis=1, join="inner")
portfolio_returns.rename(columns = {0:"my_portfolio"}, inplace=True)
portfolio_returns.head()
# Out:
#             my_portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-05-14      0.000015                   0.000000            0.000000
# 2018-05-15     -0.010064                  -0.000726           -0.001409
# 2018-05-16      0.009403                   0.008637            0.006244
# 2018-05-17     -0.001595                  -0.001955            0.002524
# 2018-05-18     -0.006061                  -0.004357           -0.002672
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# 2018-05-18                    -0.012832               -0.002212  0.002557
#
#               Algo 2     sp500
# Date
# 2018-05-14  0.001635  0.000884
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
portfolio_returns = portfolio_returns.replace(0, np.nan)
portfolio_returns.dropna(inplace=True)
portfolio_returns.head()
# Out:
#             my_portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-05-15     -0.010064                  -0.000726           -0.001409
# 2018-05-16      0.009403                   0.008637            0.006244
# 2018-05-17     -0.001595                  -0.001955            0.002524
# 2018-05-18     -0.006061                  -0.004357           -0.002672
# 2018-05-21      0.007600                   0.002503           -0.001195
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# 2018-05-18                    -0.012832               -0.002212  0.002557
# 2018-05-21                    -0.001153                0.010370 -0.003092
#
#               Algo 2     sp500
# Date
# 2018-05-15 -0.001139 -0.006842
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
portfolio_std = portfolio_returns.std()
portfolio_annualized_std = portfolio_std * np.sqrt(252)
portfolio_annualized_std
# Out:
# my_portfolio                   0.213101
# SOROS FUND MANAGEMENT LLC      0.148253
# PAULSON & CO.INC.              0.117988
# TIGER GLOBAL MANAGEMENT LLC    0.235023
# BERKSHIRE HATHAWAY INC         0.249815
# Algo 1                         0.134706
# Algo 2                         0.140362
# sp500                          0.153024
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
portfolio_rolling_21 = portfolio_returns.rolling(window=21).std()

# Plot rolling standard deviation
portfolio_rolling_21.plot(figsize=(20,10), title="Rolling 21-Day Std. of Portfolio")
# Out:
# <AxesSubplot:title={'center':'Rolling 21-Day Std. of Portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation as heatmap
portfolio_correlation = portfolio_returns.corr()
sns.heatmap(portfolio_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
## Calculate and plot Beta
# Calculate covariance of your portfolio
my_portfolio_covariance = portfolio_returns["my_portfolio"].rolling(window=60).cov(portfolio_returns["sp500"])
# Calculate variance of S&P 500
sp500_variance = portfolio_returns["sp500"].rolling(window=60).var()
# Computing beta
my_portfolio_beta = my_portfolio_covariance / sp500_variance
# Plot beta trend
my_portfolio_beta.plot(figsize=(20,10), title="Rolling 60-Day Beta of My Portfolio")
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of My Portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
portfolio_sharpe_ratio = (portfolio_returns.mean() * 252) / (portfolio_returns.std() * np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot
portfolio_sharpe_ratio.plot(kind="bar", figsize=(20,10), title="Sharpe Ratio")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratio'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
My portfolio outperforms every other portfolio except the Algo 1 portfolio.
